# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
lungcancer = pd.read_csv("lung_cancer.csv")

# %%
lungcancer
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
lungcancer.head(n=103) # Dataseti bölme
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 98       M   64        1               2        2              2
# 99       M   56        2               1        1              1
# 100      M   58        2               1        1              1
# 101      F   81        1               2        2              2
# 102      M   64        2               1        1              1
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
len(lungcancer.index) #İndex sayısı
# Out:
# 309

# %%
lungcancer["AGE"].mean() # Bulunan anket bireylerinin yaşlarının ortalaması
# Out:
# 62.67313915857605

# %%
lungcancer["AGE"].max() # Yapılan anketteki en yüksek yaşa sahip olan bireyin yaşı
# Out:
# 87

# %%
lungcancer["AGE"].min() # Yapılan anketteki en düşük yaşa sahip olan bireyin yaşı
# Out:
# 21

# %%
cancerpeopla=lungcancer[lungcancer["LUNG_CANCER"] == "YES"]  # KANSER OLANLARIN LİSTESİ

# %%
cancerpeopla
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 5        F   75        1               2        1              1
# 6        M   52        2               1        1              1
# 7        F   51        2               2        2              2
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
cancerpeopla.to_csv("Cancer_People.csv")

# %%
nocancerpeopla=lungcancer[lungcancer["LUNG_CANCER"] == "NO"]  # KANSER OLMAYANLARIN LİSTESİ

# %%
nocancerpeopla
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# 8        F   68        2               1        2              1
# 12       F   60        2               1        1              1
# 14       M   69        2               1        1              1
# 19       F   61        1               1        1              1
# 22       F   21        2               1        1              1
# 27       M   69        1               1        1              2
# 29       M   55        1               2        1              1
# 30       F   57        2               2        1              1
# 32       M   56        2               2        2              1
# 34       M   59        1               2        2              1
# ...

# %%
nocancerpeopla.to_csv("nocancer_people.csv")

# %%
lungcancer["AGE"].nunique() # KAÇ FARKLI YAŞ GRUBU OLDUĞUNU GÖSTERİR
# Out:
# 39

# %%
lungcancer["GENDER"].value_counts() # KAÇ ERKEK VE KAÇ KADIN OLDUĞUNU GÖSTERİR
# Out:
# M    162
# F    147
# Name: GENDER, dtype: int64

# %%
lungcancer["AGE"].value_counts() # YAŞ GRUPLARINDA KAÇ KİŞİ OLDUĞUNU GÖSTERİR
# Out:
# 64    20
# 63    19
# 56    19
# 62    18
# 60    17
# 61    16
# 59    15
# 70    15
# 67    13
# 58    13
# 69    11
# 55    11
# 72    10
# 71    10
# 68     9
# 57     9
# 77     9
# 51     8
# 54     8
# 65     7
# 74     6
# 75     5
# 76     4
# 52     4
# 53     4
# 73     4
# 47     4
# 66     4
# 49     3
# 81     2
# 78     2
# 44     2
# 48     2
# 21     1
# 79     1
# 38     1
# 39     1
# 87     1
# 46     1
# Name: AGE, dtype: int64

# %%
lungcancer.drop(["ANXIETY","SWALLOWING DIFFICULTY","CHRONIC DISEASE"], axis=1,inplace=True)  #RAPIDMINERDAN ÖĞRENDİĞİM ETKİSİ ÇOKTA FAZLA OLMAYAN KATEGORİLERİ ÇIKARTIYORUZ

# %%
maxage=lungcancer[lungcancer["AGE"] == lungcancer["AGE"].max()]   # EN YÜKSEK YAŞA SAHİP OLAN HASTAMIZIN ÖZELLİKLERİ # 2 = EVET 1 = NO

# %%
maxage.to_csv("maximumageperson.csv")

# %%
minage=lungcancer[lungcancer["AGE"] == lungcancer["AGE"].min()]  # EN DÜŞÜK YAŞA SAHİP OLAN HASTAMIZIN ÖZELLİKLERİ # 2 = EVET 1 = NO

# %%
minage.to_csv("minumunageperson.csv")

# %%
df = pd.DataFrame(lungcancer["AGE"].sort_values(ascending=False)) # Yaşlara göre sıralama

# %%
df
# Out:
#      AGE
# 277   87
# 83    81
# 101   81
# 204   79
# 69    78
# ..   ...
# 168   44
# 20    44
# 261   39
# 238   38
# 22    21
#
# [309 rows x 1 columns]

# %%
ismsokingyes = lungcancer[lungcancer["SMOKING"]==2] # ANKETİMİZDEKİ TOPLAM SİGARA İÇENLERİN SAYISI

# %%
ismsokingyes
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  PEER_PRESSURE  FATIGUE   ALLERGY   \
# 1        M   74        2               1              1         2         2
# 3        M   63        2               2              1         1         1
# 6        M   52        2               1              1         2         1
# 7        F   51        2               2              2         2         2
# 8        F   68        2               1              1         2         1
# ..     ...  ...      ...             ...            ...       ...       ...
# 300      F   63        2               2              2         2         2
# 302      F   65        2               2              2         2         1
# 305      M   70        2               1              1         2         2
# 306      M   58        2               1              1         1         2
# 307      M   67        2               1              1         2         2
#
# ...

# %%
ismsokingyes.to_csv("smokingpeople.csv")

# %%
issmokingcancer = ismsokingyes[ismsokingyes["LUNG_CANCER"]=="YES"]

# %%
issmokingcancer
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  PEER_PRESSURE  FATIGUE   ALLERGY   \
# 1        M   74        2               1              1         2         2
# 6        M   52        2               1              1         2         1
# 7        F   51        2               2              2         2         2
# 9        M   53        2               2              2         1         2
# 10       F   61        2               2              2         2         1
# ..     ...  ...      ...             ...            ...       ...       ...
# 300      F   63        2               2              2         2         2
# 302      F   65        2               2              2         2         1
# 305      M   70        2               1              1         2         2
# 306      M   58        2               1              1         1         2
# 307      M   67        2               1              1         2         2
#
# ...

# %%
issmokingcancer.to_csv("smokingandcancer.csv")

# %%
whatisagecancerandsmoking = issmokingcancer[issmokingcancer["AGE"] == issmokingcancer["AGE"]] #KANSER OLAN HASTALARIN YAŞLARI

# %%
whatisagecancerandsmoking  # KANSER OLUPTA SİGARA İÇEN İNSANLARIN SAYISI 155/309
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  PEER_PRESSURE  FATIGUE   ALLERGY   \
# 1        M   74        2               1              1         2         2
# 6        M   52        2               1              1         2         1
# 7        F   51        2               2              2         2         2
# 9        M   53        2               2              2         1         2
# 10       F   61        2               2              2         2         1
# ..     ...  ...      ...             ...            ...       ...       ...
# 300      F   63        2               2              2         2         2
# 302      F   65        2               2              2         2         1
# 305      M   70        2               1              1         2         2
# 306      M   58        2               1              1         1         2
# 307      M   67        2               1              1         2         2
#
# ...

# %%
smokeandshortbreath = whatisagecancerandsmoking[whatisagecancerandsmoking["SHORTNESS OF BREATH"]==2] # SİGARA İÇİPTE NEFES DARLIĞI ÇEKEN KANSER HASTALARI

# %%
smokeandshortbreath # 107/309
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  PEER_PRESSURE  FATIGUE   ALLERGY   \
# 1        M   74        2               1              1         2         2
# 6        M   52        2               1              1         2         1
# 7        F   51        2               2              2         2         2
# 10       F   61        2               2              2         2         1
# 13       M   58        2               1              1         2         2
# ..     ...  ...      ...             ...            ...       ...       ...
# 299      M   65        2               2              2         2         2
# 300      F   63        2               2              2         2         2
# 302      F   65        2               2              2         2         1
# 305      M   70        2               1              1         2         2
# 307      M   67        2               1              1         2         2
#
# ...

# %%
smokeandshortbreath.to_csv("smokingandshortbreath.csv")

# %%
chestpainandothers = smokeandshortbreath[smokeandshortbreath["CHEST PAIN"]==2] # SİGARA NEFES DARLIĞI ,KANSER AYRICA GÖĞÜS AĞRISI OLANLAR

# %%
chestpainandothers  # 63 / 309
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  PEER_PRESSURE  FATIGUE   ALLERGY   \
# 1        M   74        2               1              1         2         2
# 6        M   52        2               1              1         2         1
# 13       M   58        2               1              1         2         2
# 16       M   75        2               1              1         1         2
# 23       M   60        2               1              1         2         2
# ..     ...  ...      ...             ...            ...       ...       ...
# 295      F   54        2               2              1         1         1
# 298      M   62        2               1              1         2         1
# 300      F   63        2               2              2         2         2
# 305      M   70        2               1              1         2         2
# 307      M   67        2               1              1         2         2
#
# ...

# %%
chestpainandothers.to_csv("smoking-shortbreatandchestpaing.csv")

# %%
coughing = chestpainandothers[chestpainandothers["COUGHING"]==2] # SİGARA,GÖĞÜS AĞRISI,ÖKSÜRÜK,NEFES DARLIĞI KANSER OLAN HASTALAR

# %%
len(coughing)
# Out:
# 46

# %%
coughing # 46/309 # SİGARA,GÖĞÜS AĞRISI,ÖKSÜRÜK,NEFES DARLIĞI KANSER OLAN HASTALAR
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  PEER_PRESSURE  FATIGUE   ALLERGY   \
# 6        M   52        2               1              1         2         1
# 13       M   58        2               1              1         2         2
# 16       M   75        2               1              1         1         2
# 23       M   60        2               1              1         2         2
# 40       M   68        2               1              1         2         2
# 45       M   72        2               2              2         2         1
# 46       M   62        2               2              1         1         2
# 53       M   49        2               1              2         2         2
# 59       M   69        2               2              2         2         2
# 74       M   61        2               1              1         2         2
# 77       M   56        2               1              1         2         2
# ...

# %%
coughing.to_csv("coughing.csv")

# %%
alcoholconsumeandothers = coughing[coughing["ALCOHOL CONSUMING"]==2] # HEM ALKOL HEM SİGARA,ÖKSÜRÜK,GÖĞÜS AĞRISI NEFES DARLIĞI ÇEKENLERİN LİSTESİ

# %%
alcoholconsumeandothers #39/309
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  PEER_PRESSURE  FATIGUE   ALLERGY   \
# 6        M   52        2               1              1         2         1
# 13       M   58        2               1              1         2         2
# 16       M   75        2               1              1         1         2
# 23       M   60        2               1              1         2         2
# 40       M   68        2               1              1         2         2
# 45       M   72        2               2              2         2         1
# 53       M   49        2               1              2         2         2
# 59       M   69        2               2              2         2         2
# 74       M   61        2               1              1         2         2
# 77       M   56        2               1              1         2         2
# 94       M   48        2               1              1         2         2
# ...

# %%
alcoholconsumeandothers.to_csv("everythingandalcohol.csv")

# %%
wheezing = alcoholconsumeandothers[alcoholconsumeandothers["WHEEZING"]==2] # SİGARA,HIRILTI,ÖKSÜRÜK,GÖĞÜS AĞRISI,ALKOL ETKİSİ,NEFES DARLIĞI

# %%
wheezing #28 value /309
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  PEER_PRESSURE  FATIGUE   ALLERGY   \
# 6        M   52        2               1              1         2         1
# 13       M   58        2               1              1         2         2
# 16       M   75        2               1              1         1         2
# 23       M   60        2               1              1         2         2
# 45       M   72        2               2              2         2         1
# 53       M   49        2               1              2         2         2
# 74       M   61        2               1              1         2         2
# 77       M   56        2               1              1         2         2
# 99       M   56        2               1              1         2         2
# 102      M   64        2               1              1         2         2
# 116      M   57        2               1              1         2         1
# ...

# %%
wheezing.to_csv("wheezing.csv")

# %%
yellow_fingers = wheezing[wheezing["YELLOW_FINGERS"]==2]

# %%
yellow_fingers # POPULASYON SİGARA,((SARI PARMAK!)),TÜKENMİŞLİK,HIRILTI,ALKOL ETKİSİ,ÖKSÜRÜK,NEFES DARLIĞI VE GÖĞÜS AĞRISI OLAN BİR HASTANIN KANSER OLUP OLMADIĞI HAKKINDA BİLGİ
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  PEER_PRESSURE  FATIGUE   ALLERGY   \
# 45      M   72        2               2              2         2         1
#
#     WHEEZING  ALCOHOL CONSUMING  COUGHING  SHORTNESS OF BREATH  CHEST PAIN  \
# 45         2                  2         2                    2           2
#
#    LUNG_CANCER
# 45         YES

# %%
yellow_fingers.to_csv("yellowfingersandothers.csv")

# %%
peerpressure = wheezing[wheezing["PEER_PRESSURE"]==2] # POPULASYON, (((AKRAN BASKISI!)),TÜKENMİŞLİK,HIRILTI,ALKOL ETKİSİ,ÖKSÜRÜK,NEFES DARLIĞI VE GÖĞÜS AĞRISI OLAN BİR HASTANIN KANSER OLUP OLMADIĞI HAKKINDA BİLGİ

# %%
peerpressure # 4/309 HEPSİ ERKEK
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  PEER_PRESSURE  FATIGUE   ALLERGY   \
# 45       M   72        2               2              2         2         1
# 53       M   49        2               1              2         2         2
# 163      M   68        2               1              2         2         2
# 225      M   59        2               1              2         2         2
#
#      WHEEZING  ALCOHOL CONSUMING  COUGHING  SHORTNESS OF BREATH  CHEST PAIN  \
# 45          2                  2         2                    2           2
# 53          2                  2         2                    2           2
# 163         2                  2         2                    2           2
# 225         2                  2         2                    2           2
#
#     LUNG_CANCER
# 45          YES
# 53          YES
# 163         YES
# 225         YES

# %%
peerpressure.to_csv("peerpressure.csv")

# %%
iscancerF=lungcancer[lungcancer["GENDER"]=="F"] # ANKETTEKİ KADINLAR

# %%
iscancerF
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  PEER_PRESSURE  FATIGUE   ALLERGY   \
# 2        F   59        1               1              2         2         1
# 4        F   63        1               2              1         1         1
# 5        F   75        1               2              1         2         2
# 7        F   51        2               2              2         2         2
# 8        F   68        2               1              1         2         1
# ..     ...  ...      ...             ...            ...       ...       ...
# 295      F   54        2               2              1         1         1
# 297      F   47        2               2              2         2         2
# 300      F   63        2               2              2         2         2
# 302      F   65        2               2              2         2         1
# 304      F   56        1               1              2         2         1
#
# ...

# %%
iscancerF.to_csv("femalecancer.csv")

# %%
isfemalecancer = iscancerF[iscancerF["LUNG_CANCER"]=="YES"]

# %%
isfemalecancer #KANSER OLAN KADINLARIN SAYISI 125
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  PEER_PRESSURE  FATIGUE   ALLERGY   \
# 5        F   75        1               2              1         2         2
# 7        F   51        2               2              2         2         2
# 10       F   61        2               2              2         2         1
# 15       F   48        1               2              2         2         2
# 18       F   68        2               2              2         2         1
# ..     ...  ...      ...             ...            ...       ...       ...
# 295      F   54        2               2              1         1         1
# 297      F   47        2               2              2         2         2
# 300      F   63        2               2              2         2         2
# 302      F   65        2               2              2         2         1
# 304      F   56        1               1              2         2         1
#
# ...

# %%
iscancerm= lungcancer[lungcancer["GENDER"]=="M"] # ANKETTEKİ ERKEKLER

# %%
iscancerm
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  PEER_PRESSURE  FATIGUE   ALLERGY   \
# 0        M   69        1               2              1         2         1
# 1        M   74        2               1              1         2         2
# 3        M   63        2               2              1         1         1
# 6        M   52        2               1              1         2         1
# 9        M   53        2               2              2         1         2
# ..     ...  ...      ...             ...            ...       ...       ...
# 303      M   51        1               2              1         2         2
# 305      M   70        2               1              1         2         2
# 306      M   58        2               1              1         1         2
# 307      M   67        2               1              1         2         2
# 308      M   62        1               1              2         2         2
#
# ...

# %%
iscancermale = iscancerm[iscancerm["LUNG_CANCER"]=="YES"]

# %%
iscancermale # KANSER OLAN ERKEKLERİN SAYISI 145
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  PEER_PRESSURE  FATIGUE   ALLERGY   \
# 0        M   69        1               2              1         2         1
# 1        M   74        2               1              1         2         2
# 6        M   52        2               1              1         2         1
# 9        M   53        2               2              2         1         2
# 11       M   72        1               1              1         2         2
# ..     ...  ...      ...             ...            ...       ...       ...
# 303      M   51        1               2              1         2         2
# 305      M   70        2               1              1         2         2
# 306      M   58        2               1              1         1         2
# 307      M   67        2               1              1         2         2
# 308      M   62        1               1              2         2         2
#
# ...

# %%
iscancermale.to_csv("cancermale.csv")
